# %% [markdown]
# ![Screenshot%20%2897%29.png](attachment:Screenshot%20%2897%29.png)

# %% [markdown]
# <b>GRIP @ The Sparks Foundation - Data Science and Business Analytics

# %% [markdown]
# <b>TASK 3 : EXPLORATORY DATA ANALYSIS - RETAIL

# %% [markdown]
# <b>Author : ALEENA VADAKKEDATHU SHAJAN

# %% [markdown]
# <b>Objective : To perform 'Exploratory Data Analysis' on the dataset 'SampleSuperstore'.

# %% [markdown]
# <b>IMPORTING THE REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <b>LOADING AND READING THE DATASET

# %%
df=pd.read_csv("C:\\Users\\Aleena\\Downloads\\SampleSuperStore.csv")
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
# <b>FEATURE EXPLORATION

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# <b>VISUALIZING THE DATA - EXPLORATORY DATA ANALYSIS

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Sales'],color='blue',label='Sales',shade=True,bw=25)
sns.kdeplot(df['Profit'],color='red',label='Profit',shade=True,bw=25)
plt.xlim([-100,1000])
plt.legend()
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <b>ANALYSIS USING PAIPLOT OF EACH COLUMN

# %% [markdown]
# **1.Based on the Category**

# %%
sns.pairplot(df,hue='Category')

# %% [markdown]
# **2.Based on the Region**

# %%
sns.pairplot(df,hue='Region')

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# **HEATMAP OF CORRELATION**

# %%
sns.heatmap(df.corr(),cmap='rocket_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Count plot of each Column**

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Ship Mode'],ax=axs[1][0])
sns.countplot(df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)

plt.tight_layout()
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Quantity'])
plt.title('Quantity',fontsize=20)
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Quantity')

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Discount'])
plt.xticks(rotation=90)
plt.title('Discount',fontsize=20)
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# **Distribution of the data using the plot**

# %%
fig,axs=plt.subplots(ncols=2,nrows=2,figsize=(10,10));

sns.countplot(df['Sales'],color='blue',ax=axs[0][0])
sns.countplot(df['Profit'],color='red',ax=axs[0][1])
sns.countplot(df['Quantity'],color='green',ax=axs[1][0])
sns.countplot(df['Discount'],color='yellow',ax=axs[1][1])
axs[0][0].set_title('Sales Distribution',fontsize=20)
axs[0][1].set_title('Profit Distribution',fontsize=20)
axs[1][0].set_title('Quantity Distribution',fontsize=20)
axs[1][1].set_title('Discount Distribution',fontsize=20)

plt.show()
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ALEENA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **Statewise Deal Analysis**

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df1=df['State'].value_counts()
df1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df1.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frquency/Number of deals')
plt.xlabel('States')
plt.title('State wise Dealings',fontsize=20)
plt.show()

# %% [markdown]
# **Wyoming : Lowest Number of Deal**

# %%
df['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# **City wise analysis of dealing**

# %%
df2=df['City'].value_counts()
df2=df2.head(20)

# %%
df2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency/Number of deals')
plt.xlabel('City')

plt.title('City Wise Dealings',fontsize=20)
plt.show()

# %%
df['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# **Segment wise analysis of Profit,Discount and Sell**

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df_segment=df.groupby(['Segment'])[['Sales','Discount','Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
df_segment.plot.pie(subplots=True, autopct='%1.1f%%',figsize=(18,20),startangle=90,shadow=True,labels=df_segment.index)
plt.title('Segment Wise analysis of Sale,Discount,Profit')
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# Text(0.5, 1.0, 'Segment Wise analysis of Sale,Discount,Profit')

# %% [markdown]
# **Statewise analysis of Profit Discount and Sell**

# %%
df['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df_state=df.groupby(['State'])[['Sales','Discount','Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %% [markdown]
# **1.Statewise Profit Analysis**

# %%
df_state1=df_state.sort_values('Profit')

df_state1['Profit'].plot(kind='bar',figsize=(15,4))
plt.title('State wise analysis of Profit',fontsize=20)
plt.label('Profit Per State')
plt.xlabel('Sates')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-fc3bcf822185> in <module>
#       3 df_state1['Profit'].plot(kind='bar',figsize=(15,4))
#       4 plt.title('State wise analysis of Profit',fontsize=20)
# ----> 5 plt.label('Profit Per State')
#       6 plt.xlabel('Sates')
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'label'

# %% [markdown]
# **2.Statewise Sales Analysis**

# %%
df_state['Sales'].plot(kind='pie',figsize=(20,20),autopct='%1.1f%%',startangle=90,shadow=True)
plt.title('State wise analysis of Sales',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Sales')

# %% [markdown]
# **3.Statewise Discount Analysis**

# %%
df_state1['Discount'].plot(kind='bar',figsize=(18,5))
plt.title('State wise analysis of Discount',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %% [markdown]
# **Citywise analysis of Profit**

# %%
df_city=df.groupby(['City'])[['Sales','Discount','Profit']].mean()
df.city=df_city.sort_values('Profit')
df_city.head(10)
# Out:
# <ipython-input-32-d004478f9685>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.city=df_city.sort_values('Profit')
#                   Sales  Discount     Profit
# City
# Aberdeen      25.500000  0.000000   6.630000
# Abilene        1.392000  0.800000  -3.758400
# Akron        129.999333  0.357143  -8.887410
# Albuquerque  158.582857  0.057143  45.292007
# Alexandria   344.973125  0.000000  19.913644
# Allen         72.551500  0.375000  -9.969375
# Allentown    121.893143  0.271429 -32.350057
# Altoona       10.225500  0.450000  -0.591750
# Amarillo     377.306280  0.272000 -38.796830
# Anaheim      295.810000  0.081481  45.703837

# %%
df_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color='red')
plt.title('City wise analysis of Sales,Discount,Profit',fontsize=20)
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sales,Discount,Profit')

# %%
df_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color='green')
plt.title('City wise analysis of Sales,Discount,Profit',fontsize=20)
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sales,Discount,Profit')

# %% [markdown]
# **Quantity wise Sales,Profit and Discount Analysis**

# %%
df_quantity=df.groupby(['Quantity'])[['Sales','Discount','Profit']].mean()
df_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.354488  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %%
df_quantity.plot.pie(subplots=True, autopct='%1.1f%%',figsize=(20,20),startangle=90,shadow=True,labels=df_quantity.index)
plt.title('Quantity Wise analysis of Sale,Discount,Profit')
# Out:
# Text(0.5, 1.0, 'Quantity Wise analysis of Sale,Discount,Profit')

# %% [markdown]
# **Category wise Sales Discount and Profit**

# %%
df_category=df.groupby(['Category'])[['Sales','Discount','Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
df_category.plot.pie(subplots=True, autopct='%1.1f%%',figsize=(18,20),labels=df_category.index)
plt.title('Quantity Wise analysis of Sale,Discount,Profit')
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# Text(0.5, 1.0, 'Quantity Wise analysis of Sale,Discount,Profit')

# %% [markdown]
# **Sub-Category wise Sales,Profit and Discount**

# %%
df_sub_category=df.groupby(['Sub-Category'])[['Sales','Discount','Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %% [markdown]
# **1.Based on the Sales**

# %%
plt.figure(figsize=(15,15))
plt.pie(df_sub_category['Sales'],labels=df_sub_category.index,autopct='%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis',fontsize=20)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **2.Based on the discount**

# %%
plt.figure(figsize=(15,15))
plt.pie(df_sub_category['Discount'],labels=df_sub_category.index,autopct='%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis',fontsize=20)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **3.Based on the Profit**

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',figsize=(10,5),label=['Average Sales Price($)','Profit($)'])
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# **Region wise Analysis**

# %%
df_region=df.groupby(['Region'])[['Sales','Profit','Discount']].mean()
df_region
# Out:
#               Sales     Profit  Discount
# Region
# Central  215.772661  17.092709  0.240353
# East     238.336110  32.135808  0.145365
# South    241.803645  28.857673  0.147253
# West     226.493233  33.849032  0.109335

# %%
df_region.plot.pie(subplots=True, autopct='%1.1f%%',figsize=(18,20),labels=df_region.index)
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Profit'>,
#        <AxesSubplot:ylabel='Discount'>], dtype=object)

# %% [markdown]
# **Ship Mode wise Analysis**

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df_shipmode=df.groupby(['Ship Mode'])[['Sales','Profit','Discount']].mean()

# %%
df_shipmode.plot.pie(subplots=True, autopct='%1.1f%%',figsize=(18,20),labels=df_shipmode.index)
# Out:
# C:\Users\ALEENA\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Profit'>,
#        <AxesSubplot:ylabel='Discount'>], dtype=object)

# %% [markdown]
# <b>CONCLUSION

# %% [markdown]
# **1.From the Heat Map,**
#
#     a)The Sales and Profit are moderately correlated.
#     b)The Discount and Profit are negatively correlated.
#     c)The Quantity and Profit are less moderately correlated.
#
# **2.In the State wise analysis :**
#
#     a)California,New York and Texas were the top 3 states where the Sales was highest.
#     b)The average number of deals per state was 204.
#
# **3.In the City wise analysis :**
#
#     a)The top 3 cities where the sales was highest were New York,Los Angeles and Philadelphia.
#     b)The average number of deals per city was 19.
#
# **4.Lowest the number of deals was highest were the amount of sales.**
#
#     a)Highest amount of Sales = WYOMING11.8%).
#     b)Lowest amount of Sales = DAKOTA(0.8%).
#
# **5.In State wise profit analysis Vermount had the highest profit and Ohio had the lowest profit.**
#
# **6.In the Segment wise analysis home-office had the highest profit and sales.**
#
# **7.In the Category wise analysis,**
#
#     a)Maximum sales and profit was obtained in Technology Industry.
#     b)Minimum sales and profit was obtained in Furniture Industry.
#
# **8.Similarly,for the Sub-Category wise analysis,**
#
#     a)Binders,Machines and Tables had the highest discount.
#     b)Copiers had the highest profit and sales.
#
# **9.In Ship Mode wise Analysis sales were high for the items shipped on the same day.**
#
# **10.Profit is more than that of sales but there are some areas where the profit could be increased by including some external factors.**
